# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import numpy as np
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt

# %%
y_pred = np.array([0.1,0.2,0.3,.7,.8,.3]);
y_pred
# Out:
# array([0.1, 0.2, 0.3, 0.7, 0.8, 0.3])

# %%
y_true = np.array([0,0,0,1,1,1]);
y_true
# Out:
# array([0, 0, 0, 1, 1, 1])

# %%
roc_auc_score(y_true,y_pred)
# Out:
# 0.9444444444444444

# %%
a = np.random.rand(100)

# %%
b = np.random.rand(100)

# %%
plt.hist(a,bins=30,color='r',alpha=0.5)
plt.hist(b,bins=30,color='b',alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([6., 6., 3., 7., 4., 6., 3., 3., 3., 3., 2., 5., 4., 3., 2., 2., 2.,
#         2., 1., 3., 4., 1., 2., 4., 3., 1., 1., 3., 5., 6.]),
#  array([0.02681357, 0.05880032, 0.09078706, 0.1227738 , 0.15476054,
#         0.18674729, 0.21873403, 0.25072077, 0.28270751, 0.31469425,
#         0.346681  , 0.37866774, 0.41065448, 0.44264122, 0.47462797,
#         0.50661471, 0.53860145, 0.57058819, 0.60257493, 0.63456168,
#         0.66654842, 0.69853516, 0.7305219 , 0.76250864, 0.79449539,
#         0.82648213, 0.85846887, 0.89045561, 0.92244236, 0.9544291 ,
#         0.98641584]),
#  <a list of 30 Patch objects>)

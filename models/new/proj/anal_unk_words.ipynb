# %%
import pickle

# %%
with open('unk_words_crawl.pkl','rb') as fl:
    unk_crwl = pickle.load(fl,encoding='ASCII')

# %%
unk_crwl
# Out:
# ['khadr',
#  'murkowski',
#  'siemian',
#  'sb21',
#  'mulroney',
#  'chretien',
#  'notley',
#  'theglobeandmail',
#  'manafort',
#  'djou',
#  'gorsuch',
#  'alceste',
#  'albertans',
#  'horgan',
#  'begich',
#  'sloter',
#  'usccb',
#  'gabbard',
#  'kealoha',
#  'tfsa',
#  'kpmg',
#  'jpii',
#  'trumpster',
#  'guptas',
#  'sb91',
#  'conoco',
#  'chaput',
#  'imua',
#  'klastri',
#  'arpaio',
#  'mcguinty',
#  'fptp',
#  'massengill',
#  'shannyn',
#  'punahou',
#  'inouye',
#  'raitt',
#  'mulcair',
#  'anwr',
#  'kapolei',
#  'ibbitson',
#  'heco',
#  'zinke',
#  'poloz',
#  'rhyner',
#  'monsef',
#  'coghill',
#  'mufi',
#  '\xa0',
#  'sajjan',
#  'ᴀɴᴅ',
#  'wohlforth',
#  'helfrich',
#  'dprk',
#  'hanabusa',
#  'osweiler',
#  'ontarians',
#  'cmhc',
#  'pfds',
#  'auwe',
#  'dlnr',
#  'clallam',
#  'hirono',
#  'tokuda',
#  'lw1',
#  'nenshi',
#  'cupich',
#  'renzetti',
#  'kakaako',
#  'coupeville',
#  'zille',
#  'hilcorp',
#  'scaramucci',
#  'chenault',
#  'waianae',
# ...
